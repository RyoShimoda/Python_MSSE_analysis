# %%
from pathlib import Path
import pandas as pd

folder = r"C:\Users\sryoh\Documents\Python_MSSE_analysis\FC"

files = sorted(Path(folder).glob("*.xls"))

if not files:
    print(f"{folder} の中に .xls ファイルはありません")
else:
    dfs = []
    for file in files:
        df = pd.read_excel(file, engine="xlrd")
        dfs.append(df)

    all_df = pd.concat(dfs, ignore_index=True)
    print(f"{len(files)} 件の .xls ファイルを読み込みました")
    display(all_df)
# Out:
# 24 件の .xls ファイルを読み込みました
#      Time[sec.]     Interval   Interval.1   Interval.2      Interval.3  \
# 0    Time[sec.]  Nｺ Episodes  Nｺ Episodes  Nｺ Episodes  Time in [sec.]
# 1    Time[sec.]       Freez.          Low         High          Freez.
# 2            60            0            1            0               0
# 3           120            0            0            0               0
# 4           180            0            0            0               0
# ..          ...          ...          ...          ...             ...
# 211         180            0            0            0               0
# 212         240            3            3            1            8.74
# 213         300            9            9            0           36.48
# 214         360            4            4            0           43.18
# 215         360            0            0            0               0
#
#          Interval.4      Interval.5  Accumulated Accumulated.1 Accumulated.2  \
# 0    Time in [sec.]  Time in [sec.]  Nｺ Episodes   Nｺ Episodes   Nｺ Episodes
# 1               Low            High       Freez.           Low          High
# 2                60               0            0             1             0
# 3                60               0            0             1             0
# 4                60               0            0             1             0
# ..              ...             ...          ...           ...           ...
# 211              60               0            0             1             0
# 212            51.2            0.06            3             4             1
# 213           23.52               0           12            13             1
# 214           16.82               0           16            17             1
# 215               0               0           16            17             1
#
#       Accumulated.3   Accumulated.4   Accumulated.5
# 0    Time in [sec.]  Time in [sec.]  Time in [sec.]
# 1            Freez.             Low            High
# 2                 0              60               0
# 3                 0             120               0
# 4                 0             180               0
# ..              ...             ...             ...
# 211               0             180               0
# 212            8.74           231.2            0.06
# 213           45.22          254.72            0.06
# 214            88.4          271.54            0.06
# 215            88.4          271.54            0.06
#
# [216 rows x 13 columns]
