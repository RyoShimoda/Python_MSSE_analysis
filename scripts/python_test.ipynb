# %%
from pathlib import Path
import pandas as pd

# ファイルから特定の列、行を抽出
SED92FC = pd.read_excel(r"C:\Users\sryoh\Documents\Python_MSSE_analysis\FC\89FCSED.xls")
SED92FC = SED92FC.iloc[2:7, 4]  # 2行目から3行目まで、1列目から2列目までを抽出
print(SED92FC) 

# 一旦保留
folder = r"C:\Users\sryoh\Documents\Python_MSSE_analysis\FC"

files = sorted(Path(folder).glob("*.xls"))

if not files:
    print(f"{folder} の中に .xls ファイルはありません")
else:
    dfs = []
    for file in files:
        df = pd.read_excel(file, engine="xlrd")
        dfs.append(df)

    all_df = pd.concat(dfs, ignore_index=True)
    print(f"{len(files)} 件の .xls ファイルを読み込みました")
    display(all_df)
# Out:
# 2     3.16
# 3        0
# 4        0
# 5    32.28
# 6     49.1
# Name: Interval.3, dtype: object
# 24 件の .xls ファイルを読み込みました
#      Time[sec.]     Interval   Interval.1  \
# 0    Time[sec.]  Nｺ Episodes  Nｺ Episodes
# 1    Time[sec.]       Freez.          Low
# 2            60            0            1
# 3           120            0            0
# 4           180            0            0
# ..          ...          ...          ...
# 211         180            0            0
# 212         240            3            3
# 213         300            9            9
# 214         360            4            4
# 215         360            0            0
#
#       Interval.2      Interval.3      Interval.4  \
# 0    Nｺ Episodes  Time in [sec.]  Time in [sec.]
# 1           High          Freez.             Low
# 2              0               0              60
# 3              0               0              60
# 4              0               0              60
# ..           ...             ...             ...
# 211            0               0              60
# 212            1            8.74            51.2
# 213            0           36.48           23.52
# 214            0           43.18           16.82
# 215            0               0               0
#
#          Interval.5  Accumulated Accumulated.1  \
# 0    Time in [sec.]  Nｺ Episodes   Nｺ Episodes
# 1              High       Freez.           Low
# 2                 0            0             1
# 3                 0            0             1
# 4                 0            0             1
# ..              ...          ...           ...
# 211               0            0             1
# 212            0.06            3             4
# 213               0           12            13
# 214               0           16            17
# 215               0           16            17
#
#     Accumulated.2   Accumulated.3   Accumulated.4  \
# 0     Nｺ Episodes  Time in [sec.]  Time in [sec.]
# 1            High          Freez.             Low
# 2               0               0              60
# 3               0               0             120
# 4               0               0             180
# ..            ...             ...             ...
# 211             0               0             180
# 212             1            8.74           231.2
# 213             1           45.22          254.72
# 214             1            88.4          271.54
# 215             1            88.4          271.54
#
#       Accumulated.5
# 0    Time in [sec.]
# 1              High
# 2                 0
# 3                 0
# 4                 0
# ..              ...
# 211               0
# 212            0.06
# 213            0.06
# 214            0.06
# 215            0.06
#
# [216 rows x 13 columns]

# %%
# ファイルから特定の列、行を抽出
import os
import numpy as np
import pandas as pd
from pathlib import Path

file_path = r"C:\Users\sryoh\Documents\Python_MSSE_analysis\FC\89FCSED.xls"

SED89FC = (
    pd.read_excel(file_path)
    .iloc[2:7, [4]]  # 2行目から7行目まで、4列目を抽出
    .assign(Freezing = lambda df: df['Interval.3'] / 60 * 100 ) # Freezing列を追加
    [['Freezing']]
    .assign(
        # Time列に1から行数までの連番を追加
        Time  = lambda df: list(range(1, len(df) + 1)),
        # No列にpathからファイル名を抽出して追加
        No = lambda df: Path(file_path).stem,  
        Group = lambda df: np.select(
            # 条件のリスト：No列に各文字列が含まれているか
            condlist=[
                df['No'].str.contains('SED'),
                df['No'].str.contains('LIE'),
                df['No'].str.contains('MOE')
            ],
            # 条件にマッチしたときに入れる値のリスト
            choicelist=['SED', 'LIE', 'MOE'],
            # どれにも当てはまらない場合のデフォルト値
            default='Other'
        )
    )
)

print(SED89FC)
# Out:
#     Freezing  Time       No Group
# 2   5.266667     1  89FCSED   SED
# 3        0.0     2  89FCSED   SED
# 4        0.0     3  89FCSED   SED
# 5       53.8     4  89FCSED   SED
# 6  81.833333     5  89FCSED   SED
